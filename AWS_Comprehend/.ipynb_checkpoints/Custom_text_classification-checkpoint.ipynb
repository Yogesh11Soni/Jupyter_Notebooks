# %% [markdown]
# # AWS comprehend Preparation

# %% [markdown]
# ![image.png](attachment:dbaac213-44ec-4309-8e37-d27c6a27e493.png)$1.80

# %% [markdown]
# ![image.png](attachment:836e68f5-bc95-4bfe-a150-2490a94d60bf.png)

# %% [markdown]
# ![image.png](attachment:52724d10-1f80-49d7-bbe5-f6df1dfcdc4f.png)

# %% [markdown]
# # Train The Classifier Model

# %% [markdown]
# ![image.png](attachment:1124dd98-938f-4a9b-92e2-984980f503eb.png)

# %% [markdown]
# ![image.png](attachment:27afc0f7-bda4-4b4c-b3da-2bac476b77a6.png)

# %% [markdown]
# ## Batch Or Asynchronous Classification

# %% [markdown]
# ![image.png](attachment:5587da7b-1089-4b4a-b297-72f1365d3f68.png)

# %% [markdown]
# ![image.png](attachment:fd2b10ef-47a5-464d-aaf8-7e4320348975.png)

# %% [markdown]
# ## Real Time Classification

# %% [markdown]
# ![image.png](attachment:1f54074b-7295-4006-9dd2-99c6b1002a30.png)
